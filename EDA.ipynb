# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import csv,json

# %%
race_files = glob.glob("./data/races*.csv")
with open("./data/races1.csv") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        print(row)
# Out:
# OrderedDict([('0', 'RACE 1 (284)'), ('1', 'GOOD'), ('2', 'Restricted Race - 1400M'), ('3', '1'), ('4', '2'), ('5', 'RICH AND LUCKY(C413)'), ('6', 'Z Purton'), ('7', 'L Ho'), ('8', '120'), ('9', '1066'), ('10', '5'), ('11', '-'), ('12', '3 4 3 1'), ('13', '1:22.73'), ('14', '1.7'), ('15', '2'), ('16', '7'), ('17', 'KING DRAGON(C437)'), ('18', 'S de Sousa'), ('19', 'K L Man'), ('20', '120'), ('21', '1078'), ('22', '4'), ('23', '3/4'), ('24', '2 2 1 2'), ('25', '1:22.87'), ('26', '11'), ('27', '3'), ('28', '6'), ('29', 'INVALUABLE(D091)'), ('30', 'C Schofield'), ('31', 'R Gibson'), ('32', '120'), ('33', '1297'), ('34', '1'), ('35', '1-1/2'), ('36', '6 6 7 3'), ('37', '1:22.97'), ('38', '6.3'), ('39', '4'), ('40', '8'), ('41', 'KELMIMI WINS(C419)'), ('42', 'A Badel'), ('43', 'C H Yip'), ('44', '120'), ('45', '1087'), ('46', '3'), ('47', '3-1/4'), ('48', '5 7 5 4'), ('49', '1:23.24'), ('50', '26'), ('51', '5'), ('52', '5'), ('53', 'VICTORY FOR ALL(C342)'), ('54', 'T H So'), ('55', 'Y S Ts
# ...
